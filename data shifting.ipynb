# %%
import pandas as pd
df = pd.read_csv('D:/Research/Journal drafts/CMAQ/NEW_data/Shift data/full.csv')
df.head()
# Out:
#    Unnamed: 0  Station.ID   Latitude   Longitude    YYYYMMDDHH  AirNOW_O3  \
# 0           0  40191030.0  31.879400 -110.996399  2.021010e+09         13
# 1           1  40191020.0  32.047501 -110.773903  2.021010e+09         25
# 2           2  40191032.0  32.173100 -110.979698  2.021010e+09          4
# 3           3  40191011.0  32.205002 -110.877197  2.021010e+09         19
# 4           4  40190021.0  32.176399 -110.737801  2.021010e+09         34
#
#    CMAQ12KM_O3.ppb.  CMAQ12KM_NO2.ppb.  CMAQ12KM_CO.ppm.  EC.ug.m3.  ...  \
# 0         39.234028           1.077366          0.085297   0.149258  ...
# 1         37.542675           0.819064          0.082955   0.157215  ...
# 2         23.890942           8.429288          0.160039   1.031788  ...
# 3         30.590727           5.083599          0.146104   0.716429  ...
# 4         37.377121           0.926346          0.091229   0.188910  ...
#
#    WDIR10.degree.  WSTAR.m.s.  RGRND.W.m2.  RN.cm.  RC.cm.  CFRAC  year  \
# ...

# %%
df = df.drop(['Unnamed: 0'],axis=1)
df.head()
# Out:
#    Station.ID   Latitude   Longitude    YYYYMMDDHH  AirNOW_O3  \
# 0  40191030.0  31.879400 -110.996399  2.021010e+09         13
# 1  40191020.0  32.047501 -110.773903  2.021010e+09         25
# 2  40191032.0  32.173100 -110.979698  2.021010e+09          4
# 3  40191011.0  32.205002 -110.877197  2.021010e+09         19
# 4  40190021.0  32.176399 -110.737801  2.021010e+09         34
#
#    CMAQ12KM_O3.ppb.  CMAQ12KM_NO2.ppb.  CMAQ12KM_CO.ppm.  EC.ug.m3.  \
# 0         39.234028           1.077366          0.085297   0.149258
# 1         37.542675           0.819064          0.082955   0.157215
# 2         23.890942           8.429288          0.160039   1.031788
# 3         30.590727           5.083599          0.146104   0.716429
# 4         37.377121           0.926346          0.091229   0.188910
#
#    OC.ug.m3.  ...  WDIR10.degree.  WSTAR.m.s.  RGRND.W.m2.  RN.cm.  RC.cm.  \
# 0   1.460428  ...      169.201172         0.0          0.0     0.0     0.0
# ...

# %%
df['CMAQ12KM_NO2.ppb.'] = df['CMAQ12KM_NO2.ppb.'].shift(0)

# %%
df.head()
# Out:
#    Station.ID   Latitude   Longitude    YYYYMMDDHH  AirNOW_O3  \
# 0  40191030.0  31.879400 -110.996399  2.021010e+09         13
# 1  40191020.0  32.047501 -110.773903  2.021010e+09         25
# 2  40191032.0  32.173100 -110.979698  2.021010e+09          4
# 3  40191011.0  32.205002 -110.877197  2.021010e+09         19
# 4  40190021.0  32.176399 -110.737801  2.021010e+09         34
#
#    CMAQ12KM_O3.ppb.  CMAQ12KM_NO2.ppb.  CMAQ12KM_CO.ppm.  EC.ug.m3.  \
# 0         39.234028           1.077366          0.085297   0.149258
# 1         37.542675           0.819064          0.082955   0.157215
# 2         23.890942           8.429288          0.160039   1.031788
# 3         30.590727           5.083599          0.146104   0.716429
# 4         37.377121           0.926346          0.091229   0.188910
#
#    OC.ug.m3.  ...  WDIR10.degree.  WSTAR.m.s.  RGRND.W.m2.  RN.cm.  RC.cm.  \
# 0   1.460428  ...      169.201172         0.0          0.0     0.0     0.0
# ...

# %%
df.shape
# Out:
# (154840, 26)

# %%
#df=df.dropna() 
#df.shape

# %%
#df = df[df.AirNOW_O3!= -999]

# %%
df.head()
# Out:
#    Station.ID   Latitude   Longitude    YYYYMMDDHH  AirNOW_O3  \
# 0  40191030.0  31.879400 -110.996399  2.021010e+09         13
# 1  40191020.0  32.047501 -110.773903  2.021010e+09         25
# 2  40191032.0  32.173100 -110.979698  2.021010e+09          4
# 3  40191011.0  32.205002 -110.877197  2.021010e+09         19
# 4  40190021.0  32.176399 -110.737801  2.021010e+09         34
#
#    CMAQ12KM_O3.ppb.  CMAQ12KM_NO2.ppb.  CMAQ12KM_CO.ppm.  EC.ug.m3.  \
# 0         39.234028           1.077366          0.085297   0.149258
# 1         37.542675           0.819064          0.082955   0.157215
# 2         23.890942           8.429288          0.160039   1.031788
# 3         30.590727           5.083599          0.146104   0.716429
# 4         37.377121           0.926346          0.091229   0.188910
#
#    OC.ug.m3.  ...  WDIR10.degree.  WSTAR.m.s.  RGRND.W.m2.  RN.cm.  RC.cm.  \
# 0   1.460428  ...      169.201172         0.0          0.0     0.0     0.0
# ...

# %%
# converting year, months, days and hours into date
test=df
jan=test.loc[test['month']==1]
days=jan[(jan.day >= 1) & (jan.day <= 10)]
station=days.loc[days['Station.ID'] ==40191030.0]
jan=station
jan['date']=pd.to_datetime(jan[["year", "month", "day","hours"]])
# Out:
# C:\Users\didar\AppData\Local\Temp/ipykernel_19440/3024987566.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan['date']=pd.to_datetime(jan[["year", "month", "day","hours"]])

# %%
# changing row name
station=jan
station['CMAQ12KM_NO2']=station['CMAQ12KM_NO2.ppb.']
station.head()
# Out:
# C:\Users\didar\AppData\Local\Temp/ipykernel_19440/3440934699.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   station['CMAQ12KM_NO2']=station['CMAQ12KM_NO2.ppb.']
#      Station.ID  Latitude   Longitude    YYYYMMDDHH  AirNOW_O3  \
# 0    40191030.0   31.8794 -110.996399  2.021010e+09         13
# 28   40191030.0   31.8794 -110.996399  2.021010e+09          8
# 56   40191030.0   31.8794 -110.996399  2.021010e+09         12
# 84   40191030.0   31.8794 -110.996399  2.021010e+09         22
# 112  40191030.0   31.8794 -110.996399  2.021010e+09         33
#
#      CMAQ12KM_O3.ppb.  CMAQ12KM_NO2.ppb.  CMAQ12KM_CO.ppm.  EC.ug.m3.  \
# 0           39.234028           1.077366          0.085297   0.149258
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', size=12)
fig, ax = plt.subplots(figsize=(20, 13))

# Specify how our lines should look
#ax.plot(station.date, station.prediction, color='tab:orange', label='prediction')
# Use linestyle keyword to style our plot
ax.plot(station.date, station.AirNOW_O3, color='green', linestyle='--',
        label='AirNOW_O3')

##### remove .ppp. from QMAQ12KM_O3.ppp.

ax.plot(station.date, station.CMAQ12KM_NO2, color='blue', linestyle='--',
        label='CMAQ12KM_NO2')
# Redisplay the legend to show our new wind gust line
ax.legend(loc='upper left')
# Same as above
ax.set_xlabel('Time')
ax.set_ylabel('values')
ax.set_title('January (1-5 days)')
ax.grid(True)
ax.legend(loc='upper left');

# %%
0,2, 10, 18,
# Out:
# (0, 2, 10)
